# %% [markdown]
# ## Linear Elastic Phase Field Fracture
#
# In this tutorial, we model the deformation and fracture of linear elastic materials using FEniCSx.
#
# Consider a 2D bar $\Omega = \{(x,y): x\in (0, L),\; y\in (0,W)\}$. The bar is fixed on the left edge (at $ x=0 $),  $\Gamma_l = \{(x,y) \in \Omega: x = 0\}$, the beam's displacement is restricted in the y-direction on the bottom edge (at $ y = 0 $), $\Gamma_b = \{(x,y) \in \Omega: y=0\}$, and is subjected to a prescribed displacment $\boldsymbol{u_D}$ on the right surface (at $x=L$), $\Gamma_r = \{(x,y) \in \Omega: x = L\}$.
#
# In this model we assume that the strain is confined to the small strain theory, that the materials are homogeneous, elastic, isotropic brittle materials. Additionally, the effects of geometrical nonlinearities and possible non-symmetric behavior in the damaged portions being ignored for simplicity.
#
# The energy functional for the phase field fracture for the brittle fracture of a solid is formulated below:
#
# \begin{equation}
#     \mathcal{E}_{tot}(u,\alpha) = \mathcal{E}_{elas}(u,\alpha)+\mathcal{E}_{frac}(\alpha)-\mathcal{W}_{ext}(u)
# \end{equation}
#
# Where $\mathcal{E}_{tot}$ represents the total energy, $\mathcal{E}_{elas}$ represents the elastic energy, $\mathcal{E}_{frac}$ represents the fracture energy, and $\mathcal{W}_{ext}$ is the work done by external forces, which are represented as follows,
# \begin{equation}
#     \mathcal{E}_{elas}(u,\alpha) = \frac{1}{2}\int_{\Omega}a(\alpha)\epsilon:\mathbf{C}:\epsilon   dx
# \end{equation}
# \begin{equation}
#     \mathcal{E}_{frac}(\alpha) = \frac{G_c}{4*c_w}\int_{\Omega}\frac{w(\alpha)}{l}+l||\nabla\alpha||^2dx
# \end{equation}
# \begin{equation}
#     \mathcal{W}_{ext}(u) = \int_{\Omega}f\cdot u dx
# \end{equation}
#
# Where, $ u $ is the displacement, $ \epsilon(u) $ is the linearized strain function shown below, and $ \mathbf{C} $ is the fourth-order elasticity tensor of the material before it is damaged. $ G_c$ is the critical fracture energy, $ l $ is the regularization length scale parameter, $f$ is the external force and $ \alpha \in [0,1]$ is the continuous field that represents the crack. Where, $ \alpha = 0 $ represents the undamaged material and $ \alpha = 1 $ represents the damaged or cracked material.
#
# \begin{equation}
#     \epsilon(u) = \nabla u(x) + (\nabla u(x))^T
# \end{equation}
#
# The degradation function $a(\alpha)$, the strictly increasing function $w(\alpha)$, and it's corresponding constant $c_w$ for the linear elastic case are as follows.
# \begin{equation}
#     a(\alpha) = (1 - \alpha)^2 + k_{res}
# \end{equation}
# \begin{equation}
#     w(\alpha) = \alpha,
#     c_w = \int_{0}^{1}\sqrt{w(\alpha)}d\alpha =  \frac{2}{3}
# \end{equation}
#
# ### Geometrical, material, and external loading parameters and functions
# In what follows, we let $ L = 1 mm $ and $ H = 0.3 mm $. We assume that there is no applied body force, i.e., $ f = 0 $. The prescribed displacement $ \boldsymbol u_D = 6.447200e-01 mm $ applied on the x-direction only on the right edge $ \Gamma_r $.
#
# As for the material properties, we take Young's modulus $E = 1.84 MPa $, Poisson ratio $\nu = 0.3 $, critical fracture energy $ G_c = 0.0489  N/mm $. These properties are typical of rubber-like materials.
#
# The second material property is a metallic material which is included for cases with two materials, such as inclusions or a split material bar. The material properties, we take Young's modulus $ E = 1600000 Mpa $, Poisson ratio $ \nu = 0.24 $, critical fracture energy $ G_c = 0.189 N/mm $.

# %% [markdown]
# #### FEniCSx implementation
# We start by loading in the relavent packages

# %%
# dolfinx from the fenicx library with specific functions 
import dolfinx 
from dolfinx import mesh, fem, plot, io, la 
from dolfinx.io import gmshio
import dolfinx.fem.petsc
import petsc4py
from petsc4py import PETSc
import gmsh

# mpi4py for parallel execution 
import mpi4py
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# scientific computation and math 
import numpy as np 
import sympy
import ufl

# plotting and visualization 
import matplotlib.pyplot as plt
import pyvista 

import os 
import sys 
from typing import Optional

#specific functions from supporting modules 
from solvers import LinearSolver, AlphaSolver
from func import create_functions, AltMin, MeshPlotter, material_properties, unpack_functions
from form_prob import form_prob
from bound_cond import prescribed_disp_x, prescribed_disp_y

# %% [markdown]
# Next, we create a results directory.

# %%
# Results folder labeled for the geometry of the model and the direction of loading 
results_folder = "pfm_result/notched_x"
if rank == 0: 
    os.makedirs(results_folder, exist_ok=True)

# %% [markdown]
# Now, the model and the mesh are created using the gmsh library.

# %%
gmsh.initialize()

# Creates and names the model 
gmsh.model.add("notched_F")

# Build geometry
# Creates points at the verticies of the model 
gmsh.model.occ.addPoint(0, 0, 0, 0.1, 1)
gmsh.model.occ.addPoint(1, 0, 0, 0.1, 2)
gmsh.model.occ.addPoint(1, 0.3, 0, 0.1, 3)
gmsh.model.occ.addPoint(0, 0.3, 0, 0.1, 4)
gmsh.model.occ.addPoint(0.255, 0, 0, 0.1, 5)
gmsh.model.occ.addPoint(0.265, 0, 0, 0.1, 6)
gmsh.model.occ.addPoint(0.26, 0.03, 0, 0.1, 7)
# Creates the lines that connect the vertices of the model 
gmsh.model.occ.addLine(1, 5, 1)
gmsh.model.occ.addLine(5, 7, 2)
gmsh.model.occ.addLine(7, 6, 3)
gmsh.model.occ.addLine(6, 2, 4)
gmsh.model.occ.addLine(2, 3, 5)
gmsh.model.occ.addLine(3, 4, 6)
gmsh.model.occ.addLine(4, 1, 7)
gmsh.model.occ.addLine(1, 2, 8)
# Creates the curve loop used to define the plane surface 
gmsh.model.occ.addCurveLoop([1, 2, 3, 4, 5, 6, 7], 1)
# Creates the plane surface of the model
gmsh.model.occ.addPlaneSurface([1], 1)

gmsh.model.occ.synchronize()

# Adds physical groups
gmsh.model.addPhysicalGroup(2, [1], 1)  # 2D surface
gmsh.model.addPhysicalGroup(1, [1, 2, 3, 4, 5, 6, 7], 6)  # 1D boundary lines

# Gets the boundaries and creating boundary arrays 
boundary = gmsh.model.getBoundary([(2, 1)], oriented=False)
xBot, xTop, yBot, yTop = [], [], [], []
for dim, tag in boundary:
    x, y, _ = gmsh.model.occ.getCenterOfMass(dim, tag)
    if np.isclose(x, 0.0, atol=1e-6):
        xBot.append(tag)
    elif np.isclose(x, 1.0, atol=1e-6):
        xTop.append(tag)
    elif np.isclose(y, 0.0, atol=1e-6):
        yBot.append(tag)
    elif np.isclose(y, 0.3, atol=1e-6):
        yTop.append(tag)    

# Adds physical groups for boundaries 
gmsh.model.addPhysicalGroup(1, xBot, 2)
gmsh.model.setPhysicalName(1, 2, "xBot")
gmsh.model.addPhysicalGroup(1, xTop, 3)
gmsh.model.setPhysicalName(1, 3, "xTop")
gmsh.model.addPhysicalGroup(1, yTop, 4)
gmsh.model.setPhysicalName(1, 4, "yTop")
gmsh.model.addPhysicalGroup(1, yBot, 5)
gmsh.model.setPhysicalName(1, 5, "yBot")

# Sets the regularization length scale range 
gmsh.option.setNumber("Mesh.CharacteristicLengthMin", 0.01)
gmsh.option.setNumber("Mesh.CharacteristicLengthMax", 0.015)

# Generates the mesh 
gmsh.model.mesh.generate(2)
gmsh.write("notched_rectangle.msh")
print("Mesh Written")

# Converts to dolfinx mesh
domain, cell_tags, facet_tags = gmshio.model_to_mesh(gmsh.model, comm=MPI.COMM_WORLD, rank=0, gdim=2)
print("Mesh Imported")

gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 60%] Meshing curve 5 (Line)
# Info    : [ 70%] Meshing curve 6 (Line)
# Info    : [ 80%] Meshing curve 7 (Line)
# Info    : [ 90%] Meshing curve 8 (Line)
# Info    : Done meshing 1D (Wall 0.0019135s, CPU 0.002368s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.166012s, CPU 0.165342s)
# Info    : 1846 nodes 3632 elements
# Info    : Writing 'notched_rectangle.msh'...
# Mesh Written
# Info    : Done writing 'notched_rectangle.msh'
# Mesh Imported

# %% [markdown]
# Next, we create the domain topology and the connectivity. Additionally, we run the MeshPlotter to visualize the mesh.

# %%
# Creates the domain topology and the connectivity
tdim = domain.topology.dim
domain.topology.create_connectivity(tdim, tdim)

# Plots the geometry and mesh
plotter = MeshPlotter(domain, tdim, cell_tags)
plotter.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %% [markdown]
# Then we define the material properties, and the dimesions of the model.

# %%
omega_L, omega_H = 1.0, 0.3 #mm
material_1 = {"E1": 1.84, "Gc1": 0.0489, "nu1": 0.3}
# E: Mpa, Gc: N/mm, nu: unitless
material_2 = {"E2": 1600000, "Gc2": 0.189, "nu2":0.24}
top_tag = 1

properties = material_properties(material_1, material_2, domain, cell_tags, top_tag)
# Out:
# Tag 1 has 3379 cells

# %%
matl_type = {"hyperelastic": False} #Selecting the material model type

#Setting initial values fo later calculations 
ell_ = 0.01 # Characteristic length 
E_0 = fem.Constant(domain, PETSc.ScalarType(material_1["E1"])) # young's modulus
Gc_0 = fem.Constant(domain, PETSc.ScalarType(material_1["Gc1"])) # Critical Fracture energy 

conditions = {"E_0": E_0, "Gc_0": Gc_0, "ell_": ell_}

# %% [markdown]
# Then the test and trial functions and funciton spaces are created for both the displacement and damage variables.

# %%
state, spaces, bounds, dx, ds = create_functions(domain) # Creating the test and trial functions and spaces 
u, alpha, alpha_low, alpha_up, V_u, V_alpha = unpack_functions(state, spaces, bounds) #Unpacking the variables from their dictionaries

# %% [markdown]
# The boundary conditions and initital loading are then created using the bound_cond module. The loading is a prescribed displacement

# %%
bcu, bcalpha, u_D = prescribed_disp_x(domain, V_u, V_alpha, facet_tags) # Establishes the boundary conditions and the loading 
bcs = {"bcu": bcu, "bcalpha": bcalpha} # Dictionary of combined boundary conditions

# %% [markdown]
# Now we create the total energy functional, the initial guess for the loading, and establish the displacemnt and damage solvers.

# %%
total_energy, init, solver_u, damage_problem = form_prob(state, conditions, properties, tdim, dx, domain, matl_type, spaces, bcs, bounds)
# Out:
# c_w =  8/3
# ell =  0.01
# init =  0.00017160499171694368

# %%
#Creates a folder and sets up the ability to write the displacement and the damage to .bp file readable in parview
filename = results_folder + "/solution"
file_results = io.VTXWriter(domain.comm, filename + ".bp", [u,alpha], engine="BP4")

# %% [markdown]
# Then, we apply the prescribed displacement in increments to the model.

# %%
#!!Unchanged from newfrac-fenicsx-training!! alpha_low us renamed for clarity
load0 = float(init)*omega_L # reference value for the loading (imposed displacement)
loads = load0*np.linspace(0, 3757, 500)

energies = np.zeros((len(loads),4))
iterations = np.zeros((len(loads),2))

alt_min_parameters = {"atol": 1.e-6,"max_iter": 100}
alt_min = AltMin(state, alt_min_parameters, dx, solver_u, damage_problem, file_results)
with alpha.x.petsc_vec.localForm() as alpha_local:
    alpha_local.set(0)

for i_t, t in enumerate(loads):
    u_D.value = t

    alt_min.set_load(t)
    # update the lower bound
    alpha.x.petsc_vec.copy(alpha_low.x.petsc_vec)    
    print(f"-- Solving for t = {t:3.2f} --")
    alt_min.alternate_minimization(parameters=alt_min_parameters, monitor=alt_min.monitor)
    file_results.write(i_t)
# Out:
# -- Solving for t = 0.00 --
# Load: 0.000000e+00, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 0.0000e+00, min(u) = 0.0000e+00
# -- Solving for t = 0.00 --
# Load: 1.292024e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2920e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.00 --
# Load: 2.584048e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5840e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.00 --
# Load: 3.876072e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.8761e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 5.168096e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.1681e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 6.460120e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4601e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 7.752144e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.7521e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 9.044168e-03, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.0442e-03, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 1.033619e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0336e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 1.162822e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1628e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 1.292024e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2920e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.01 --
# Load: 1.421226e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4212e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 1.550429e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5504e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 1.679631e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6796e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 1.808834e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8088e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 1.938036e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9380e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 2.067238e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0672e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 2.196441e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1964e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 2.325643e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3256e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.02 --
# Load: 2.454846e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4548e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 2.584048e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5840e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 2.713250e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7133e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 2.842453e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8425e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 2.971655e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9717e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 3.100857e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1009e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 3.230060e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2301e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 3.359262e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3593e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.03 --
# Load: 3.488465e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4885e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 3.617667e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.6177e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 3.746869e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.7469e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 3.876072e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.8761e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 4.005274e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.0053e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 4.134477e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.1345e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 4.263679e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.2637e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.04 --
# Load: 4.392881e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.3929e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 4.522084e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.5221e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 4.651286e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.6513e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 4.780489e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.7805e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 4.909691e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 4.9097e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 5.038893e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.0389e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 5.168096e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.1681e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 5.297298e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.2973e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.05 --
# Load: 5.426501e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.4265e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 5.555703e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.5557e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 5.684905e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.6849e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 5.814108e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.8141e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 5.943310e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 5.9433e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 6.072513e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.0725e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 6.201715e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.2017e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 6.330917e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.3309e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.06 --
# Load: 6.460120e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4601e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 6.589322e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.5893e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 6.718525e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.7185e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 6.847727e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.8477e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 6.976929e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.9769e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 7.106132e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.1061e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 7.235334e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.2353e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 7.364537e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.3645e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.07 --
# Load: 7.493739e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.4937e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 7.622941e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.6229e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 7.752144e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.7521e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 7.881346e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 7.8813e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 8.010549e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.0105e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 8.139751e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.1398e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 8.268953e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.2690e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.08 --
# Load: 8.398156e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.3982e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 8.527358e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.5274e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 8.656561e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.6566e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 8.785763e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.7858e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 8.914965e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 8.9150e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 9.044168e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.0442e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 9.173370e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.1734e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 9.302572e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.3026e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.09 --
# Load: 9.431775e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.4318e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 9.560977e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.5610e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 9.690180e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.6902e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 9.819382e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.8194e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 9.948584e-02, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 9.9486e-02, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 1.007779e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0078e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 1.020699e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0207e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 1.033619e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0336e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.10 --
# Load: 1.046539e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0465e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.059460e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0595e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.072380e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0724e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.085300e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0853e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.098220e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.0982e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.111141e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1111e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.124061e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1241e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.136981e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1370e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.11 --
# Load: 1.149901e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1499e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.162822e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1628e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.175742e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1757e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.188662e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.1887e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.201582e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2016e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.214503e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2145e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.227423e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2274e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.12 --
# Load: 1.240343e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2403e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.253263e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2533e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.266183e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2662e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.279104e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2791e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.292024e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.2920e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.304944e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3049e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.317864e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3179e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.330785e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3308e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.13 --
# Load: 1.343705e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3437e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.356625e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3566e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.369545e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3695e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.382466e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3825e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.395386e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.3954e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.408306e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4083e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.421226e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4212e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.434147e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4341e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.14 --
# Load: 1.447067e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4471e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.459987e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4600e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.472907e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4729e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.485828e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4858e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.498748e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.4987e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.511668e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5117e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.524588e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5246e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.15 --
# Load: 1.537509e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5375e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.550429e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5504e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.563349e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5633e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.576269e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5763e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.589189e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.5892e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.602110e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6021e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.615030e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6150e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.627950e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6280e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.16 --
# Load: 1.640870e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6409e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.653791e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6538e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.666711e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6667e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.679631e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6796e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.692551e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.6926e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.705472e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7055e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.718392e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7184e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.731312e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7313e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.17 --
# Load: 1.744232e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7442e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.757153e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7572e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.770073e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7701e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.782993e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7830e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.795913e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.7959e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.808834e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8088e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.821754e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8218e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.834674e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8347e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.18 --
# Load: 1.847594e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8476e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.860514e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8605e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.873435e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8734e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.886355e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8864e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.899275e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.8993e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.912195e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9122e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.925116e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9251e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.19 --
# Load: 1.938036e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9380e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 1.950956e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9510e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 1.963876e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9639e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 1.976797e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9768e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 1.989717e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 1.9897e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 2.002637e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0026e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 2.015557e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0156e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 2.028478e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0285e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.20 --
# Load: 2.041398e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0414e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.054318e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0543e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.067238e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0672e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.080159e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0802e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.093079e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.0931e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.105999e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1060e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.118919e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1189e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.131840e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1318e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.21 --
# Load: 2.144760e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1448e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.157680e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1577e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.170600e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1706e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.183520e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1835e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.196441e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.1964e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.209361e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2094e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.222281e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2223e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.235201e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2352e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.22 --
# Load: 2.248122e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2481e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.261042e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2610e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.273962e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2740e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.286882e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2869e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.299803e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.2998e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.312723e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3127e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.325643e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3256e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.23 --
# Load: 2.338563e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3386e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.351484e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3515e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.364404e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3644e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.377324e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3773e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.390244e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.3902e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.403165e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4032e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.416085e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4161e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.429005e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4290e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.24 --
# Load: 2.441925e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4419e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.454846e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4548e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.467766e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4678e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.480686e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4807e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.493606e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.4936e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.506526e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5065e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.519447e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5194e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.532367e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5324e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.25 --
# Load: 2.545287e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5453e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.558207e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5582e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.571128e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5711e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.584048e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5840e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.596968e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.5970e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.609888e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6099e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.622809e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6228e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.635729e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6357e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.26 --
# Load: 2.648649e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6486e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.661569e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6616e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.674490e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6745e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.687410e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.6874e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.700330e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7003e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.713250e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7133e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.726171e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7262e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.27 --
# Load: 2.739091e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7391e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.752011e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7520e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.764931e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7649e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.777852e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7779e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.790772e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.7908e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.803692e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8037e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.816612e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8166e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.829532e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8295e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.28 --
# Load: 2.842453e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8425e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.855373e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8554e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.868293e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8683e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.881213e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8812e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.894134e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.8941e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.907054e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9071e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.919974e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9200e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.932894e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9329e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.29 --
# Load: 2.945815e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9458e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 2.958735e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9587e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 2.971655e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9717e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 2.984575e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9846e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 2.997496e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 2.9975e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 3.010416e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0104e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 3.023336e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0233e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 3.036256e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0363e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.30 --
# Load: 3.049177e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0492e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.062097e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0621e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.075017e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0750e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.087937e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.0879e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.100857e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1009e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.113778e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1138e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.126698e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1267e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.31 --
# Load: 3.139618e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1396e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.152538e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1525e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.165459e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1655e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.178379e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1784e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.191299e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.1913e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.204219e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2042e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.217140e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2171e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.230060e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2301e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.32 --
# Load: 3.242980e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2430e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.255900e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2559e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.268821e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2688e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.281741e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2817e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.294661e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.2947e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.307581e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3076e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.320502e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3205e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.333422e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3334e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.33 --
# Load: 3.346342e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3463e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.359262e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3593e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.372183e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3722e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.385103e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3851e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.398023e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.3980e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.410943e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4109e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.423863e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4239e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.436784e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4368e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.34 --
# Load: 3.449704e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4497e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.462624e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4626e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.475544e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4755e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.488465e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.4885e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.501385e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.5014e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.514305e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.5143e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# Load: 3.527225e-01, Iteration:   0, Error: 0.0000e+00
#   max(alpha) = 0.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 3.5272e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.35 --
# ...
#   max(alpha) = 3.0223e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  46, Error: 5.1607e-06
#   max(alpha) = 3.0253e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  47, Error: 5.0075e-06
#   max(alpha) = 3.0282e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  48, Error: 4.8599e-06
#   max(alpha) = 3.0310e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  49, Error: 4.7178e-06
#   max(alpha) = 3.0338e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  50, Error: 4.5808e-06
#   max(alpha) = 3.0364e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  51, Error: 4.4488e-06
#   max(alpha) = 3.0390e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  52, Error: 4.3215e-06
#   max(alpha) = 3.0415e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  53, Error: 4.1987e-06
#   max(alpha) = 3.0439e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  54, Error: 4.0802e-06
#   max(alpha) = 3.0463e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  55, Error: 3.9658e-06
#   max(alpha) = 3.0486e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  56, Error: 3.8554e-06
#   max(alpha) = 3.0509e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  57, Error: 3.7487e-06
#   max(alpha) = 3.0530e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  58, Error: 3.6456e-06
#   max(alpha) = 3.0551e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  59, Error: 3.5459e-06
#   max(alpha) = 3.0572e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  60, Error: 3.4495e-06
#   max(alpha) = 3.0592e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  61, Error: 3.3564e-06
#   max(alpha) = 3.0612e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  62, Error: 3.2662e-06
#   max(alpha) = 3.0631e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  63, Error: 3.1790e-06
#   max(alpha) = 3.0649e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  64, Error: 3.0945e-06
#   max(alpha) = 3.0667e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  65, Error: 3.0127e-06
#   max(alpha) = 3.0684e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  66, Error: 2.9335e-06
#   max(alpha) = 3.0701e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  67, Error: 2.8568e-06
#   max(alpha) = 3.0718e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  68, Error: 2.7825e-06
#   max(alpha) = 3.0734e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  69, Error: 2.7104e-06
#   max(alpha) = 3.0750e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  70, Error: 2.6406e-06
#   max(alpha) = 3.0765e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  71, Error: 2.5728e-06
#   max(alpha) = 3.0780e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  72, Error: 2.5071e-06
#   max(alpha) = 3.0795e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  73, Error: 2.4434e-06
#   max(alpha) = 3.0809e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  74, Error: 2.3816e-06
#   max(alpha) = 3.0823e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  75, Error: 2.3216e-06
#   max(alpha) = 3.0836e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  76, Error: 2.2633e-06
#   max(alpha) = 3.0849e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  77, Error: 2.2068e-06
#   max(alpha) = 3.0862e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  78, Error: 2.1518e-06
#   max(alpha) = 3.0875e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  79, Error: 2.0985e-06
#   max(alpha) = 3.0887e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  80, Error: 2.0467e-06
#   max(alpha) = 3.0899e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  81, Error: 1.9963e-06
#   max(alpha) = 3.0910e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  82, Error: 1.9474e-06
#   max(alpha) = 3.0922e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  83, Error: 1.8998e-06
#   max(alpha) = 3.0933e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  84, Error: 1.8536e-06
#   max(alpha) = 3.0943e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  85, Error: 1.8087e-06
#   max(alpha) = 3.0954e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  86, Error: 1.7650e-06
#   max(alpha) = 3.0964e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  87, Error: 1.7224e-06
#   max(alpha) = 3.0974e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  88, Error: 1.6811e-06
#   max(alpha) = 3.0984e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  89, Error: 1.6409e-06
#   max(alpha) = 3.0993e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  90, Error: 1.6017e-06
#   max(alpha) = 3.1003e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  91, Error: 1.5636e-06
#   max(alpha) = 3.1012e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  92, Error: 1.5265e-06
#   max(alpha) = 3.1021e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  93, Error: 1.4904e-06
#   max(alpha) = 3.1029e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  94, Error: 1.4553e-06
#   max(alpha) = 3.1038e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  95, Error: 1.4211e-06
#   max(alpha) = 3.1046e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  96, Error: 1.3878e-06
#   max(alpha) = 3.1054e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  97, Error: 1.3553e-06
#   max(alpha) = 3.1062e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  98, Error: 1.3237e-06
#   max(alpha) = 3.1070e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# Load: 6.434279e-01, Iteration:  99, Error: 1.2929e-06
#   max(alpha) = 3.1077e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4343e-01, min(u) = 0.0000e+00
# -- Solving for t = 0.64 --
# Load: 6.447200e-01, Iteration:   0, Error: 4.0490e-05
#   max(alpha) = 3.1282e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   1, Error: 3.7903e-05
#   max(alpha) = 3.1497e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   2, Error: 3.6925e-05
#   max(alpha) = 3.1711e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   3, Error: 3.6205e-05
#   max(alpha) = 3.1920e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   4, Error: 3.5583e-05
#   max(alpha) = 3.2127e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   5, Error: 3.5535e-05
#   max(alpha) = 3.2331e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   6, Error: 3.6757e-05
#   max(alpha) = 3.2535e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   7, Error: 3.7947e-05
#   max(alpha) = 3.2744e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   8, Error: 3.9178e-05
#   max(alpha) = 3.2959e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:   9, Error: 4.0496e-05
#   max(alpha) = 3.3180e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  10, Error: 4.1920e-05
#   max(alpha) = 3.3409e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  11, Error: 4.5169e-05
#   max(alpha) = 3.3649e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  12, Error: 5.1352e-05
#   max(alpha) = 3.3908e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  13, Error: 5.8296e-05
#   max(alpha) = 3.4200e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  14, Error: 6.6202e-05
#   max(alpha) = 3.4530e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  15, Error: 7.5322e-05
#   max(alpha) = 3.4905e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  16, Error: 8.5898e-05
#   max(alpha) = 3.5333e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  17, Error: 9.8219e-05
#   max(alpha) = 3.5822e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  18, Error: 1.1264e-04
#   max(alpha) = 3.6383e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  19, Error: 1.2961e-04
#   max(alpha) = 3.7027e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  20, Error: 1.4969e-04
#   max(alpha) = 3.7771e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  21, Error: 1.7361e-04
#   max(alpha) = 3.8633e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  22, Error: 2.0231e-04
#   max(alpha) = 3.9636e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  23, Error: 2.3699e-04
#   max(alpha) = 4.0809e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  24, Error: 2.7927e-04
#   max(alpha) = 4.2189e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  25, Error: 3.3124e-04
#   max(alpha) = 4.3822e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  26, Error: 3.9570e-04
#   max(alpha) = 4.5767e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  27, Error: 4.7636e-04
#   max(alpha) = 4.8099e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  28, Error: 5.8435e-04
#   max(alpha) = 5.0931e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  29, Error: 7.3376e-04
#   max(alpha) = 5.4428e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  30, Error: 9.7068e-04
#   max(alpha) = 5.8791e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  31, Error: 1.3602e-03
#   max(alpha) = 6.4380e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  32, Error: 1.9396e-03
#   max(alpha) = 7.1668e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  33, Error: 2.7610e-03
#   max(alpha) = 8.0873e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  34, Error: 3.7874e-03
#   max(alpha) = 9.1190e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  35, Error: 5.1484e-03
#   max(alpha) = 9.9992e-01, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = 0.0000e+00
# Load: 6.447200e-01, Iteration:  36, Error: 6.6637e-03
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -9.1311e-03
# Load: 6.447200e-01, Iteration:  37, Error: 8.1846e-03
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -2.2992e-02
# Load: 6.447200e-01, Iteration:  38, Error: 1.0217e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -3.4193e-02
# Load: 6.447200e-01, Iteration:  39, Error: 1.3009e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -2.9325e-02
# Load: 6.447200e-01, Iteration:  40, Error: 1.4303e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -2.1342e-02
# Load: 6.447200e-01, Iteration:  41, Error: 1.5527e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -2.6793e-02
# Load: 6.447200e-01, Iteration:  42, Error: 1.7677e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -3.4002e-02
# Load: 6.447200e-01, Iteration:  43, Error: 2.0176e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -4.2735e-02
# Load: 6.447200e-01, Iteration:  44, Error: 2.1442e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -4.4791e-02
# Load: 6.447200e-01, Iteration:  45, Error: 2.5340e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -4.4170e-02
# Load: 6.447200e-01, Iteration:  46, Error: 3.4666e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -4.7724e-02
# Load: 6.447200e-01, Iteration:  47, Error: 3.7419e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -3.6350e-02
# Load: 6.447200e-01, Iteration:  48, Error: 2.9229e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -4.0035e-03
# Load: 6.447200e-01, Iteration:  49, Error: 3.0940e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -3.5640e-05
# Load: 6.447200e-01, Iteration:  50, Error: 1.6293e-02
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -3.7723e-03
# Load: 6.447200e-01, Iteration:  51, Error: 5.8847e-03
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -2.6189e-05
# Load: 6.447200e-01, Iteration:  52, Error: 3.1238e-07
#   max(alpha) = 1.0000e+00, min(alpha) = 0.0000e+00
#   max(u) = 6.4472e-01, min(u) = -1.3043e-05

# %% [markdown]
# ### Results
# The results file is a .bp file which is readable in paraview version 5.11.2. The results are viewed by adjusting the coloring tab to either damage or displacement, and setting the automatic rescale range mode to clamp and update at every timestep.

# %% [markdown]
# #### Displacement Results (mm)
# ![dis.png](attachment:315bd346-378e-48b9-83a6-6a98f20babf4.png)

# %% [markdown]
# #### Damage Results (alpha)
# ![dam.png](attachment:e22294cb-15ac-4329-a187-2d43b677c340.png)
